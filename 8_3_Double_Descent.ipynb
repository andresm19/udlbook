# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-r_qc0n33
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-r_qc0n33
#   Resolved https://github.com/greydanus/mnist1d to commit 350929d12f4c9a4b7355e0c96604e41b9239bdb4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (3.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post9) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post9) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post9) (2024.7.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post9) (1.16.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post9-py3-none-any.whl size=14496 sha256=92245a4fb9cbe0b8994ae46036e997024c3b32477f93a7f27fdc6040b48af1c3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1n2r2m5b/wheels/41/95/55/45fcf7d38cfa97e35682da6c5017d4513729131326ce935371
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post9

# %%
# %pip install torch
# %pip install mnist1
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.3.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl (19.7 MB)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.20 nvidia-nvtx-cu12-12.1.105
# ERROR: Could not find a version that satisfies the requirement mnist1 (from versions: none)
# ERROR: No matching distribution found for mnist1

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.299854, train error 88.55,  test loss 2.298689, test error 88.50
# Epoch   100, train loss 1.920658, train error 72.62,  test loss 1.761433, test error 69.68
# Epoch   200, train loss 1.915282, train error 71.68,  test loss 1.739441, test error 68.80
# Epoch   300, train loss 1.907927, train error 71.50,  test loss 1.740162, test error 69.50
# Epoch   400, train loss 1.905497, train error 72.28,  test loss 1.737398, test error 69.30
# Epoch   500, train loss 1.903634, train error 71.53,  test loss 1.729587, test error 69.53
# Epoch   600, train loss 1.902316, train error 71.12,  test loss 1.726815, test error 69.05
# Epoch   700, train loss 1.901827, train error 71.00,  test loss 1.733229, test error 68.90
# Epoch   800, train loss 1.901000, train error 71.65,  test loss 1.730275, test error 68.65
# Epoch   900, train loss 1.901800, train error 70.75,  test loss 1.727093, test error 68.60
# Training model with   4 hidden variables
# Epoch     0, train loss 2.285192, train error 86.85,  test loss 2.285770, test error 87.53
# Epoch   100, train loss 1.789076, train error 66.95,  test loss 1.646465, test error 64.93
# Epoch   200, train loss 1.764795, train error 64.95,  test loss 1.610656, test error 61.97
# Epoch   300, train loss 1.758989, train error 64.38,  test loss 1.596761, test error 62.60
# Epoch   400, train loss 1.755429, train error 63.90,  test loss 1.595365, test error 61.80
# Epoch   500, train loss 1.748564, train error 63.60,  test loss 1.588792, test error 61.35
# Epoch   600, train loss 1.734832, train error 62.72,  test loss 1.555206, test error 60.35
# Epoch   700, train loss 1.726680, train error 62.90,  test loss 1.554581, test error 60.22
# Epoch   800, train loss 1.728056, train error 63.47,  test loss 1.551932, test error 59.47
# Epoch   900, train loss 1.723245, train error 63.35,  test loss 1.542749, test error 59.97
# Training model with   6 hidden variables
# Epoch     0, train loss 2.216876, train error 84.15,  test loss 2.190620, test error 83.18
# Epoch   100, train loss 1.709116, train error 63.30,  test loss 1.558220, test error 60.55
# Epoch   200, train loss 1.679883, train error 60.97,  test loss 1.529675, test error 59.20
# Epoch   300, train loss 1.639846, train error 59.92,  test loss 1.466126, test error 57.28
# Epoch   400, train loss 1.622729, train error 58.72,  test loss 1.476443, test error 57.58
# Epoch   500, train loss 1.613087, train error 58.42,  test loss 1.477998, test error 56.67
# Epoch   600, train loss 1.602309, train error 57.58,  test loss 1.475473, test error 57.10
# Epoch   700, train loss 1.600101, train error 57.53,  test loss 1.475950, test error 57.08
# Epoch   800, train loss 1.600003, train error 57.58,  test loss 1.468789, test error 57.00
# Epoch   900, train loss 1.591799, train error 57.03,  test loss 1.465483, test error 57.35
# Training model with   8 hidden variables
# Epoch     0, train loss 2.289380, train error 88.65,  test loss 2.286576, test error 88.85
# Epoch   100, train loss 1.591976, train error 56.12,  test loss 1.409148, test error 54.05
# Epoch   200, train loss 1.551204, train error 54.40,  test loss 1.377225, test error 52.25
# Epoch   300, train loss 1.519644, train error 53.38,  test loss 1.348994, test error 51.20
# Epoch   400, train loss 1.496130, train error 52.50,  test loss 1.332118, test error 51.12
# Epoch   500, train loss 1.477736, train error 51.53,  test loss 1.326664, test error 50.75
# Epoch   600, train loss 1.484062, train error 52.10,  test loss 1.350179, test error 51.83
# Epoch   700, train loss 1.470231, train error 51.60,  test loss 1.330623, test error 50.78
# Epoch   800, train loss 1.468261, train error 51.72,  test loss 1.348750, test error 51.45
# Epoch   900, train loss 1.460043, train error 50.75,  test loss 1.336247, test error 50.28
# Training model with  10 hidden variables
# Epoch     0, train loss 2.153626, train error 79.70,  test loss 2.118031, test error 79.55
# Epoch   100, train loss 1.481051, train error 49.78,  test loss 1.327816, test error 48.70
# Epoch   200, train loss 1.428265, train error 47.30,  test loss 1.286005, test error 46.45
# Epoch   300, train loss 1.402706, train error 47.30,  test loss 1.258469, test error 45.28
# Epoch   400, train loss 1.398388, train error 47.85,  test loss 1.253922, test error 46.17
# Epoch   500, train loss 1.388628, train error 46.67,  test loss 1.260211, test error 46.28
# Epoch   600, train loss 1.380056, train error 46.62,  test loss 1.252865, test error 45.67
# Epoch   700, train loss 1.371089, train error 45.45,  test loss 1.251881, test error 45.45
# Epoch   800, train loss 1.363893, train error 45.42,  test loss 1.266037, test error 46.22
# Epoch   900, train loss 1.365721, train error 45.47,  test loss 1.265963, test error 46.05
# Training model with  14 hidden variables
# Epoch     0, train loss 2.204215, train error 82.20,  test loss 2.187964, test error 82.53
# Epoch   100, train loss 1.388747, train error 46.12,  test loss 1.267804, test error 47.47
# Epoch   200, train loss 1.313599, train error 43.78,  test loss 1.233371, test error 45.35
# Epoch   300, train loss 1.289905, train error 43.58,  test loss 1.249948, test error 46.83
# Epoch   400, train loss 1.264541, train error 42.72,  test loss 1.264453, test error 47.97
# Epoch   500, train loss 1.250054, train error 41.78,  test loss 1.274201, test error 47.47
# Epoch   600, train loss 1.242167, train error 41.70,  test loss 1.292096, test error 48.00
# Epoch   700, train loss 1.233861, train error 41.40,  test loss 1.307472, test error 47.97
# Epoch   800, train loss 1.223719, train error 41.20,  test loss 1.313460, test error 48.17
# Epoch   900, train loss 1.217830, train error 40.55,  test loss 1.317656, test error 47.97
# Training model with  18 hidden variables
# Epoch     0, train loss 2.128702, train error 80.07,  test loss 2.104592, test error 79.65
# Epoch   100, train loss 1.348784, train error 45.90,  test loss 1.319478, test error 50.30
# Epoch   200, train loss 1.258869, train error 42.72,  test loss 1.350563, test error 50.45
# Epoch   300, train loss 1.219491, train error 42.03,  test loss 1.367903, test error 50.30
# Epoch   400, train loss 1.206652, train error 41.15,  test loss 1.427198, test error 51.28
# Epoch   500, train loss 1.173649, train error 40.15,  test loss 1.430373, test error 50.58
# Epoch   600, train loss 1.152809, train error 39.58,  test loss 1.460482, test error 50.50
# Epoch   700, train loss 1.151944, train error 39.58,  test loss 1.481718, test error 50.95
# Epoch   800, train loss 1.133118, train error 39.72,  test loss 1.539674, test error 51.05
# Epoch   900, train loss 1.128486, train error 39.10,  test loss 1.545120, test error 50.78
# Training model with  22 hidden variables
# Epoch     0, train loss 2.166876, train error 80.22,  test loss 2.140358, test error 80.35
# Epoch   100, train loss 1.269898, train error 43.25,  test loss 1.276519, test error 48.95
# Epoch   200, train loss 1.137989, train error 38.12,  test loss 1.347490, test error 49.38
# Epoch   300, train loss 1.093385, train error 36.75,  test loss 1.423100, test error 51.05
# Epoch   400, train loss 1.073375, train error 36.42,  test loss 1.478299, test error 50.25
# Epoch   500, train loss 1.032362, train error 35.05,  test loss 1.521087, test error 49.60
# Epoch   600, train loss 1.013138, train error 34.32,  test loss 1.538382, test error 50.30
# Epoch   700, train loss 1.008689, train error 34.30,  test loss 1.609338, test error 51.53
# Epoch   800, train loss 1.008800, train error 34.38,  test loss 1.641970, test error 51.78
# Epoch   900, train loss 0.984055, train error 34.28,  test loss 1.688056, test error 51.60
# Training model with  26 hidden variables
# Epoch     0, train loss 2.225951, train error 83.03,  test loss 2.226638, test error 83.68
# Epoch   100, train loss 1.189649, train error 39.20,  test loss 1.312539, test error 48.10
# Epoch   200, train loss 1.033508, train error 33.75,  test loss 1.377955, test error 48.38
# Epoch   300, train loss 0.965009, train error 31.75,  test loss 1.525673, test error 50.45
# Epoch   400, train loss 0.908448, train error 30.75,  test loss 1.626114, test error 50.97
# Epoch   500, train loss 0.891421, train error 30.35,  test loss 1.753892, test error 51.20
# Epoch   600, train loss 0.848107, train error 28.00,  test loss 1.860601, test error 52.28
# Epoch   700, train loss 0.830592, train error 27.50,  test loss 1.956239, test error 53.12
# Epoch   800, train loss 0.813098, train error 27.90,  test loss 2.024282, test error 52.80
# Epoch   900, train loss 0.814022, train error 27.22,  test loss 2.063221, test error 52.72
# Training model with  30 hidden variables
# Epoch     0, train loss 2.119662, train error 79.40,  test loss 2.070622, test error 79.78
# Epoch   100, train loss 1.084485, train error 34.70,  test loss 1.348066, test error 49.30
# Epoch   200, train loss 0.922748, train error 30.28,  test loss 1.564405, test error 51.20
# Epoch   300, train loss 0.845427, train error 28.22,  test loss 1.767715, test error 52.80
# Epoch   400, train loss 0.783880, train error 26.38,  test loss 1.948493, test error 53.85
# Epoch   500, train loss 0.751778, train error 25.12,  test loss 2.085105, test error 53.33
# Epoch   600, train loss 0.731010, train error 24.82,  test loss 2.223756, test error 53.70
# Epoch   700, train loss 0.694643, train error 22.95,  test loss 2.359266, test error 55.08
# Epoch   800, train loss 0.685937, train error 23.22,  test loss 2.377376, test error 54.28
# Epoch   900, train loss 0.670802, train error 22.72,  test loss 2.523643, test error 55.00
# Training model with  35 hidden variables
# Epoch     0, train loss 2.108745, train error 78.38,  test loss 2.057323, test error 78.30
# Epoch   100, train loss 1.021686, train error 33.90,  test loss 1.390535, test error 49.15
# Epoch   200, train loss 0.812889, train error 27.50,  test loss 1.707043, test error 50.58
# Epoch   300, train loss 0.686684, train error 22.82,  test loss 1.999543, test error 52.70
# Epoch   400, train loss 0.637900, train error 21.88,  test loss 2.322780, test error 53.65
# Epoch   500, train loss 0.566979, train error 19.25,  test loss 2.636957, test error 54.65
# Epoch   600, train loss 0.515071, train error 17.47,  test loss 2.945461, test error 55.22
# Epoch   700, train loss 0.500681, train error 16.78,  test loss 3.243623, test error 55.78
# Epoch   800, train loss 0.471894, train error 16.22,  test loss 3.616414, test error 56.22
# Epoch   900, train loss 0.460954, train error 16.53,  test loss 3.886245, test error 56.92
# Training model with  40 hidden variables
# Epoch     0, train loss 2.120610, train error 78.18,  test loss 2.085032, test error 78.45
# Epoch   100, train loss 0.901011, train error 28.80,  test loss 1.348991, test error 48.05
# Epoch   200, train loss 0.630446, train error 21.30,  test loss 1.770323, test error 51.08
# Epoch   300, train loss 0.495696, train error 16.22,  test loss 2.289418, test error 52.05
# Epoch   400, train loss 0.402595, train error 13.28,  test loss 2.910213, test error 52.22
# Epoch   500, train loss 0.385991, train error 12.85,  test loss 3.619216, test error 53.28
# Epoch   600, train loss 0.323026, train error 11.28,  test loss 4.225899, test error 53.83
# Epoch   700, train loss 0.322786, train error 11.70,  test loss 4.959508, test error 53.90
# Epoch   800, train loss 0.359206, train error 13.40,  test loss 5.639260, test error 55.08
# Epoch   900, train loss 0.252302, train error 9.07,  test loss 6.234703, test error 55.00
# Training model with  45 hidden variables
# Epoch     0, train loss 2.070556, train error 76.47,  test loss 2.015780, test error 76.07
# Epoch   100, train loss 0.807194, train error 26.03,  test loss 1.510722, test error 51.55
# Epoch   200, train loss 0.478460, train error 15.20,  test loss 2.226592, test error 52.60
# Epoch   300, train loss 0.302477, train error 9.40,  test loss 3.246150, test error 54.30
# Epoch   400, train loss 0.236788, train error 8.43,  test loss 4.491684, test error 55.25
# Epoch   500, train loss 0.188556, train error 6.57,  test loss 5.904233, test error 56.80
# Epoch   600, train loss 0.094403, train error 2.90,  test loss 6.901981, test error 56.53
# Epoch   700, train loss 0.011746, train error 0.00,  test loss 7.917175, test error 56.28
# Epoch   800, train loss 0.007785, train error 0.00,  test loss 8.551146, test error 56.42
# Epoch   900, train loss 0.005809, train error 0.00,  test loss 9.030595, test error 56.47
# Training model with  50 hidden variables
# Epoch     0, train loss 2.087673, train error 77.60,  test loss 2.051418, test error 77.75
# Epoch   100, train loss 0.694440, train error 22.90,  test loss 1.568251, test error 50.15
# Epoch   200, train loss 0.315939, train error 9.00,  test loss 2.590629, test error 52.90
# Epoch   300, train loss 0.117306, train error 2.72,  test loss 4.203770, test error 54.33
# Epoch   400, train loss 0.023021, train error 0.00,  test loss 5.692742, test error 55.03
# Epoch   500, train loss 0.011553, train error 0.00,  test loss 6.555147, test error 55.55
# Epoch   600, train loss 0.007475, train error 0.00,  test loss 7.123011, test error 55.60
# Epoch   700, train loss 0.005395, train error 0.00,  test loss 7.563931, test error 55.78
# Epoch   800, train loss 0.004212, train error 0.00,  test loss 7.905035, test error 55.60
# Epoch   900, train loss 0.003419, train error 0.00,  test loss 8.196268, test error 55.60
# Training model with  55 hidden variables
# Epoch     0, train loss 2.056928, train error 76.22,  test loss 2.012236, test error 76.00
# Epoch   100, train loss 0.646276, train error 20.45,  test loss 1.598372, test error 50.08
# Epoch   200, train loss 0.224373, train error 5.47,  test loss 2.925813, test error 53.30
# Epoch   300, train loss 0.039330, train error 0.03,  test loss 4.585941, test error 54.40
# Epoch   400, train loss 0.013742, train error 0.00,  test loss 5.508825, test error 54.47
# Epoch   500, train loss 0.007859, train error 0.00,  test loss 6.094494, test error 54.45
# Epoch   600, train loss 0.005476, train error 0.00,  test loss 6.525112, test error 54.53
# Epoch   700, train loss 0.004100, train error 0.00,  test loss 6.851822, test error 54.58
# Epoch   800, train loss 0.003259, train error 0.00,  test loss 7.124762, test error 54.67
# Epoch   900, train loss 0.002687, train error 0.00,  test loss 7.355802, test error 54.55
# Training model with  60 hidden variables
# Epoch     0, train loss 2.050450, train error 76.38,  test loss 2.029320, test error 76.32
# Epoch   100, train loss 0.524551, train error 15.65,  test loss 1.772974, test error 50.38
# Epoch   200, train loss 0.110466, train error 1.38,  test loss 3.516966, test error 54.47
# Epoch   300, train loss 0.019318, train error 0.00,  test loss 4.872669, test error 54.70
# Epoch   400, train loss 0.009347, train error 0.00,  test loss 5.550830, test error 54.65
# Epoch   500, train loss 0.005901, train error 0.00,  test loss 6.017437, test error 54.78
# Epoch   600, train loss 0.004235, train error 0.00,  test loss 6.358872, test error 54.58
# Epoch   700, train loss 0.003265, train error 0.00,  test loss 6.627496, test error 54.58
# Epoch   800, train loss 0.002629, train error 0.00,  test loss 6.853189, test error 54.67
# Epoch   900, train loss 0.002190, train error 0.00,  test loss 7.044759, test error 54.67
# Training model with  70 hidden variables
# Epoch     0, train loss 2.013747, train error 74.75,  test loss 1.944709, test error 73.78
# Epoch   100, train loss 0.332777, train error 8.32,  test loss 1.850703, test error 50.92
# Epoch   200, train loss 0.030613, train error 0.00,  test loss 3.334056, test error 52.08
# Epoch   300, train loss 0.010618, train error 0.00,  test loss 4.017779, test error 52.17
# Epoch   400, train loss 0.005992, train error 0.00,  test loss 4.418429, test error 52.53
# Epoch   500, train loss 0.004032, train error 0.00,  test loss 4.697808, test error 52.55
# Epoch   600, train loss 0.003003, train error 0.00,  test loss 4.913418, test error 52.50
# Epoch   700, train loss 0.002346, train error 0.00,  test loss 5.085027, test error 52.58
# Epoch   800, train loss 0.001916, train error 0.00,  test loss 5.228354, test error 52.60
# Epoch   900, train loss 0.001611, train error 0.00,  test loss 5.351853, test error 52.50
# Training model with  80 hidden variables
# Epoch     0, train loss 2.029680, train error 74.90,  test loss 1.977241, test error 76.07
# Epoch   100, train loss 0.213679, train error 2.95,  test loss 2.145091, test error 52.42
# Epoch   200, train loss 0.019140, train error 0.00,  test loss 3.540348, test error 53.38
# Epoch   300, train loss 0.007854, train error 0.00,  test loss 4.116898, test error 53.47
# Epoch   400, train loss 0.004623, train error 0.00,  test loss 4.442427, test error 53.47
# Epoch   500, train loss 0.003205, train error 0.00,  test loss 4.680072, test error 53.38
# Epoch   600, train loss 0.002414, train error 0.00,  test loss 4.866870, test error 53.45
# Epoch   700, train loss 0.001914, train error 0.00,  test loss 5.016972, test error 53.47
# Epoch   800, train loss 0.001576, train error 0.00,  test loss 5.143919, test error 53.53
# Epoch   900, train loss 0.001332, train error 0.00,  test loss 5.254399, test error 53.60
# Training model with  90 hidden variables
# Epoch     0, train loss 2.017604, train error 74.62,  test loss 1.931710, test error 73.12
# Epoch   100, train loss 0.167733, train error 1.65,  test loss 2.107926, test error 51.38
# Epoch   200, train loss 0.015694, train error 0.00,  test loss 3.195771, test error 50.50
# Epoch   300, train loss 0.006818, train error 0.00,  test loss 3.648412, test error 51.05
# Epoch   400, train loss 0.004103, train error 0.00,  test loss 3.922114, test error 50.95
# Epoch   500, train loss 0.002874, train error 0.00,  test loss 4.116096, test error 50.95
# Epoch   600, train loss 0.002179, train error 0.00,  test loss 4.269026, test error 50.92
# Epoch   700, train loss 0.001736, train error 0.00,  test loss 4.394228, test error 50.88
# Epoch   800, train loss 0.001433, train error 0.00,  test loss 4.499495, test error 50.80
# Epoch   900, train loss 0.001215, train error 0.00,  test loss 4.590041, test error 50.88
# Training model with 100 hidden variables
# Epoch     0, train loss 1.987546, train error 73.05,  test loss 1.937583, test error 74.18
# Epoch   100, train loss 0.085928, train error 0.10,  test loss 2.195198, test error 49.92
# Epoch   200, train loss 0.011570, train error 0.00,  test loss 2.994614, test error 50.35
# Epoch   300, train loss 0.005443, train error 0.00,  test loss 3.345255, test error 50.88
# Epoch   400, train loss 0.003413, train error 0.00,  test loss 3.559365, test error 51.10
# Epoch   500, train loss 0.002431, train error 0.00,  test loss 3.718726, test error 51.00
# Epoch   600, train loss 0.001867, train error 0.00,  test loss 3.844839, test error 51.00
# Epoch   700, train loss 0.001502, train error 0.00,  test loss 3.949174, test error 51.10
# Epoch   800, train loss 0.001249, train error 0.00,  test loss 4.037520, test error 51.22
# Epoch   900, train loss 0.001065, train error 0.00,  test loss 4.113843, test error 51.17
# Training model with 120 hidden variables
# Epoch     0, train loss 1.995823, train error 74.25,  test loss 1.913363, test error 74.03
# Epoch   100, train loss 0.051195, train error 0.00,  test loss 2.224404, test error 50.90
# Epoch   200, train loss 0.009436, train error 0.00,  test loss 2.848531, test error 51.22
# Epoch   300, train loss 0.004642, train error 0.00,  test loss 3.130832, test error 51.15
# Epoch   400, train loss 0.002968, train error 0.00,  test loss 3.311542, test error 51.08
# Epoch   500, train loss 0.002139, train error 0.00,  test loss 3.442935, test error 50.97
# Epoch   600, train loss 0.001653, train error 0.00,  test loss 3.547180, test error 51.05
# Epoch   700, train loss 0.001337, train error 0.00,  test loss 3.633390, test error 51.00
# Epoch   800, train loss 0.001117, train error 0.00,  test loss 3.707924, test error 51.05
# Epoch   900, train loss 0.000955, train error 0.00,  test loss 3.771666, test error 51.17
# Training model with 140 hidden variables
# Epoch     0, train loss 1.969008, train error 71.85,  test loss 1.943848, test error 73.68
# Epoch   100, train loss 0.034054, train error 0.00,  test loss 2.132311, test error 49.28
# Epoch   200, train loss 0.007951, train error 0.00,  test loss 2.592894, test error 49.00
# Epoch   300, train loss 0.004104, train error 0.00,  test loss 2.813186, test error 49.05
# Epoch   400, train loss 0.002673, train error 0.00,  test loss 2.960170, test error 49.15
# Epoch   500, train loss 0.001947, train error 0.00,  test loss 3.070952, test error 49.17
# Epoch   600, train loss 0.001515, train error 0.00,  test loss 3.158421, test error 49.08
# Epoch   700, train loss 0.001230, train error 0.00,  test loss 3.230093, test error 49.10
# Epoch   800, train loss 0.001030, train error 0.00,  test loss 3.292912, test error 49.17
# Epoch   900, train loss 0.000883, train error 0.00,  test loss 3.346808, test error 49.28
# Training model with 160 hidden variables
# Epoch     0, train loss 1.938716, train error 71.78,  test loss 1.873768, test error 73.05
# Epoch   100, train loss 0.026723, train error 0.00,  test loss 2.121695, test error 49.83
# Epoch   200, train loss 0.006988, train error 0.00,  test loss 2.520579, test error 49.65
# Epoch   300, train loss 0.003705, train error 0.00,  test loss 2.714760, test error 49.53
# Epoch   400, train loss 0.002447, train error 0.00,  test loss 2.846750, test error 49.47
# Epoch   500, train loss 0.001796, train error 0.00,  test loss 2.945589, test error 49.15
# Epoch   600, train loss 0.001404, train error 0.00,  test loss 3.024908, test error 49.15
# Epoch   700, train loss 0.001145, train error 0.00,  test loss 3.090914, test error 49.17
# Epoch   800, train loss 0.000962, train error 0.00,  test loss 3.146953, test error 49.15
# Epoch   900, train loss 0.000827, train error 0.00,  test loss 3.196680, test error 49.08
# Training model with 180 hidden variables
# Epoch     0, train loss 1.935805, train error 70.90,  test loss 1.862224, test error 72.62
# Epoch   100, train loss 0.023942, train error 0.00,  test loss 2.071450, test error 49.08
# Epoch   200, train loss 0.006498, train error 0.00,  test loss 2.428799, test error 48.90
# Epoch   300, train loss 0.003475, train error 0.00,  test loss 2.610115, test error 48.72
# Epoch   400, train loss 0.002303, train error 0.00,  test loss 2.730567, test error 48.72
# Epoch   500, train loss 0.001696, train error 0.00,  test loss 2.821611, test error 48.70
# Epoch   600, train loss 0.001329, train error 0.00,  test loss 2.895381, test error 48.70
# Epoch   700, train loss 0.001085, train error 0.00,  test loss 2.956674, test error 48.80
# Epoch   800, train loss 0.000912, train error 0.00,  test loss 3.009178, test error 48.72
# Epoch   900, train loss 0.000784, train error 0.00,  test loss 3.054874, test error 48.67
# Training model with 200 hidden variables
# Epoch     0, train loss 1.940514, train error 70.22,  test loss 1.890888, test error 72.47
# Epoch   100, train loss 0.021314, train error 0.00,  test loss 2.002557, test error 48.08
# Epoch   200, train loss 0.006067, train error 0.00,  test loss 2.320189, test error 48.22
# Epoch   300, train loss 0.003303, train error 0.00,  test loss 2.481410, test error 47.95
# Epoch   400, train loss 0.002200, train error 0.00,  test loss 2.592702, test error 47.92
# Epoch   500, train loss 0.001625, train error 0.00,  test loss 2.675428, test error 47.85
# Epoch   600, train loss 0.001277, train error 0.00,  test loss 2.741823, test error 47.90
# Epoch   700, train loss 0.001045, train error 0.00,  test loss 2.797410, test error 48.05
# Epoch   800, train loss 0.000880, train error 0.00,  test loss 2.845355, test error 47.97
# Epoch   900, train loss 0.000757, train error 0.00,  test loss 2.886854, test error 47.97
# Training model with 250 hidden variables
# Epoch     0, train loss 1.870541, train error 67.95,  test loss 1.803719, test error 70.18
# Epoch   100, train loss 0.017031, train error 0.00,  test loss 1.864528, test error 46.90
# Epoch   200, train loss 0.005372, train error 0.00,  test loss 2.115659, test error 46.67
# Epoch   300, train loss 0.002993, train error 0.00,  test loss 2.245888, test error 46.62
# Epoch   400, train loss 0.002019, train error 0.00,  test loss 2.335880, test error 46.53
# Epoch   500, train loss 0.001503, train error 0.00,  test loss 2.404342, test error 46.60
# Epoch   600, train loss 0.001187, train error 0.00,  test loss 2.459561, test error 46.65
# Epoch   700, train loss 0.000974, train error 0.00,  test loss 2.506078, test error 46.70
# Epoch   800, train loss 0.000823, train error 0.00,  test loss 2.546610, test error 46.78
# Epoch   900, train loss 0.000710, train error 0.00,  test loss 2.581714, test error 46.83
# Training model with 300 hidden variables
# Epoch     0, train loss 1.893026, train error 68.43,  test loss 1.814359, test error 70.25
# Epoch   100, train loss 0.014886, train error 0.00,  test loss 1.869317, test error 47.62
# Epoch   200, train loss 0.004910, train error 0.00,  test loss 2.094730, test error 47.90
# Epoch   300, train loss 0.002775, train error 0.00,  test loss 2.215729, test error 47.60
# Epoch   400, train loss 0.001890, train error 0.00,  test loss 2.300098, test error 47.47
# Epoch   500, train loss 0.001413, train error 0.00,  test loss 2.363230, test error 47.42
# Epoch   600, train loss 0.001120, train error 0.00,  test loss 2.414202, test error 47.33
# Epoch   700, train loss 0.000922, train error 0.00,  test loss 2.457405, test error 47.38
# Epoch   800, train loss 0.000780, train error 0.00,  test loss 2.494760, test error 47.47
# Epoch   900, train loss 0.000674, train error 0.00,  test loss 2.527276, test error 47.45
# Training model with 400 hidden variables
# Epoch     0, train loss 1.849204, train error 66.90,  test loss 1.783804, test error 68.88
# Epoch   100, train loss 0.011603, train error 0.00,  test loss 1.843958, test error 47.67
# Epoch   200, train loss 0.004155, train error 0.00,  test loss 2.029395, test error 46.92
# Epoch   300, train loss 0.002406, train error 0.00,  test loss 2.134763, test error 46.80
# Epoch   400, train loss 0.001659, train error 0.00,  test loss 2.207800, test error 46.88
# Epoch   500, train loss 0.001251, train error 0.00,  test loss 2.263143, test error 46.72
# Epoch   600, train loss 0.000997, train error 0.00,  test loss 2.308968, test error 46.70
# Epoch   700, train loss 0.000824, train error 0.00,  test loss 2.346728, test error 46.85
# Epoch   800, train loss 0.000700, train error 0.00,  test loss 2.379571, test error 46.80
# Epoch   900, train loss 0.000606, train error 0.00,  test loss 2.408351, test error 46.83

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
